# %% [markdown]
# Ejecucion del modelo:
#
#
#
# *   Ir a la ruta: C:\Users\grupo>cd final_projec_v2
# *   Ejecutar <python -m http.server 8000>
#
# *   Ir a chrome://flags/#enable-experimental-web-platform-features y habilitar Experimental Web Platform features
# *   abrir en chrome http://localhost:8000/index.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)
